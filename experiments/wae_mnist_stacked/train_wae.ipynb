# %%
from importlib import reload
import argparse
import os
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import math

import torchvision.transforms as transforms
from torchvision.utils import save_image

from torch.utils.data import DataLoader
from torchvision import datasets
from torch.autograd import Variable

import torch.nn as nn
import torch.nn.functional as F
import torch

import gan

cuda = torch.cuda.is_available()

print("Cuda: " + str(cuda))
Tensor = torch.cuda.FloatTensor if cuda else torch.FloatTensor
# Out:
# Cuda: True
# Cuda: True

# %%
reload(gan)
gan.train()
# Out:
# Cuda: True
# 0
# [Epoch 0/10000] [Discriminator Loss: 0.000542] [Generator Loss: -0.502085] [Reconstruction Loss: 1.220774]
# 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-1fc48b2450e7> in <module>()
#       1 reload(gan)
# ----> 2 gan.train()
#
# ~/sandbox/experiments/wae_mnist_stacked/gan.py in train(save_model, filename, num_epochs, num_samples_per_batch, latent_dim, disp_interval, lr)
#     243                 D_fake = D(z_fake)
#     244
# --> 245                 D_loss = -(torch.mean(D_real) - torch.mean(D_fake))
#     246
#     247                 D_loss.backward()
#
# KeyboardInterrupt:
